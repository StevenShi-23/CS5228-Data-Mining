# %% [markdown]
# ## Initial understanding of the data, brainstorming for discussion at the meeting

# %%
#load packages
import sys #access to system parameters https://docs.python.org/3/library/sys.html
print("Python version: {}". format(sys.version))

import pandas as pd #collection of functions for data processing and analysis modeled after R dataframes with SQL like features
print("pandas version: {}". format(pd.__version__))

import matplotlib #collection of functions for scientific and publication-ready visualization
print("matplotlib version: {}". format(matplotlib.__version__))

import numpy as np #foundational package for scientific computing
print("NumPy version: {}". format(np.__version__))

import scipy as sp #collection of functions for scientific computing and advance mathematics
print("SciPy version: {}". format(sp.__version__)) 

import IPython
from IPython import display #pretty printing of dataframes in Jupyter notebook
print("IPython version: {}". format(IPython.__version__)) 

import sklearn #collection of machine learning algorithms
print("scikit-learn version: {}". format(sklearn.__version__))

#misc libraries
import random
import time


#ignore warnings
import warnings
warnings.filterwarnings('ignore')
print('-'*25)
# Out:
# Python version: 3.9.7 (default, Sep 16 2021, 08:50:36)
# [Clang 10.0.0 ]
# pandas version: 1.4.1
# matplotlib version: 3.4.3
# NumPy version: 1.20.3
# SciPy version: 1.7.1
# IPython version: 7.29.0
# scikit-learn version: 0.24.2
# -------------------------

# %%
#Common Model Algorithms
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
from xgboost import XGBClassifier

#Common Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics

#Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pandas.plotting import scatter_matrix

#Configure Visualization Defaults
#%matplotlib inline = show plots in Jupyter Notebook browser
# %matplotlib inline
mpl.style.use('ggplot')
sns.set_style('white')
pylab.rcParams['figure.figsize'] = 12,8

# %%
data_raw = pd.read_csv("dataset/train.csv")
data_val  = pd.read_csv("dataset/train.csv")


#to play with our data we'll create a copy
#remember python assignment or equal passes by reference vs values, so we use the copy function: https://stackoverflow.com/questions/46327494/python-pandas-dataframe-copydeep-false-vs-copydeep-true-vs
data1 = data_raw.copy(deep = True)

#however passing by reference is convenient, because we can clean both datasets at once
data_cleaner = [data1, data_val]

#preview data
print (data_raw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26048 entries, 0 to 26047
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   listing_id      26048 non-null  int64
#  1   name            26048 non-null  object
#  2   street          26048 non-null  object
#  3   type            26048 non-null  object
#  4   model           24768 non-null  object
#  5   market_segment  26048 non-null  object
#  6   type_of_area    26048 non-null  object
#  7   bedrooms        25644 non-null  object
#  8   bathrooms       24812 non-null  float64
#  9   district        26048 non-null  int64
#  10  region          26048 non-null  object
#  11  planning_area   26048 non-null  object
#  12  subszone        26048 non-null  object
#  13  lat             26048 non-null  float64
#  14  lng             26048 non-null  float64
#  15  tenure          25761 non-null  object
#  16  built_year      16005 non-null  float64
#  17  no_of_units     25006 non-null  float64
#  18  area_size       26046 non-null  float64
#  19  eco_category    26048 non-null  object
#  20  accessibility   26048 non-null  object
#  21  date_listed     26048 non-null  object
#  22  price           26048 non-null  float64
# dtypes: float64(7), int64(2), object(14)
# memory usage: 4.6+ MB
# None

# %%
print('Train columns with null values:\n', data1.isnull().sum())
print("-"*10)

print('Test/Validation columns with null values:\n', data_val.isnull().sum())
print("-"*10)

data_raw.describe(include = 'all')
# Out:
# Train columns with null values:
#  listing_id            0
# name                  0
# street                0
# type                  0
# model              1280
# market_segment        0
# type_of_area          0
# bedrooms            404
# bathrooms          1236
# district              0
# region                0
# planning_area         0
# subszone              0
# lat                   0
# lng                   0
# tenure              287
# built_year        10043
# no_of_units        1042
# area_size             2
# eco_category          0
# accessibility         0
# date_listed           0
# price                 0
# dtype: int64
# ----------
# Test/Validation columns with null values:
#  listing_id            0
# name                  0
# street                0
# type                  0
# model              1280
# market_segment        0
# type_of_area          0
# bedrooms            404
# bathrooms          1236
# district              0
# region                0
# planning_area         0
# subszone              0
# lat                   0
# lng                   0
# tenure              287
# built_year        10043
# no_of_units        1042
# area_size             2
# eco_category          0
# accessibility         0
# date_listed           0
# price                 0
# dtype: int64
# ----------
#           listing_id                   name          street       type  \
# count   2.604800e+04                  26048           26048      26048
# unique           NaN                   1650            3442          2
# top              NaN  marina one residences  23 marina way   apartment
# freq             NaN                    668             274      13958
# mean    5.495573e+06                    NaN             NaN        NaN
# std     2.608064e+06                    NaN             NaN        NaN
# min     1.000122e+06                    NaN             NaN        NaN
# 25%     3.229224e+06                    NaN             NaN        NaN
# 50%     5.486808e+06                    NaN             NaN        NaN
# 75%     7.764926e+06                    NaN             NaN        NaN
# max     9.999807e+06                    NaN             NaN        NaN
#
#             model market_segment type_of_area bedrooms     bathrooms  \
# count       24768          26048        26048    25644  24812.000000
# unique         14              1            1       17           NaN
# top     apartment            ocr       strata        3           NaN
# freq        13306          26048        26048     7306           NaN
# mean          NaN            NaN          NaN      NaN      2.278091
# std           NaN            NaN          NaN      NaN      1.147204
# min           NaN            NaN          NaN      NaN      1.000000
# 25%           NaN            NaN          NaN      NaN      1.000000
# 50%           NaN            NaN          NaN      NaN      2.000000
# 75%           NaN            NaN          NaN      NaN      3.000000
# max           NaN            NaN          NaN      NaN     10.000000
#
#             district  ...           lat           lng              tenure  \
# count   26048.000000  ...  26048.000000  26048.000000               25761
# unique           NaN  ...           NaN           NaN                  53
# top              NaN  ...           NaN           NaN  leasehold/99 years
# freq             NaN  ...           NaN           NaN               15300
# mean       12.211609  ...      1.321145    103.846138                 NaN
# std         7.020134  ...      0.038569      0.049865                 NaN
# min         1.000000  ...      1.239337    103.696215                 NaN
# 25%         7.000000  ...      1.296472    103.820262                 NaN
# 50%        11.000000  ...      1.313384    103.843081                 NaN
# 75%        18.000000  ...      1.341210    103.879673                 NaN
# max        28.000000  ...      1.456436    103.976016                 NaN
#
#           built_year   no_of_units     area_size   eco_category  \
# count   16005.000000  25006.000000  26046.000000          26048
# unique           NaN           NaN           NaN              1
# top              NaN           NaN           NaN  uncategorized
# freq             NaN           NaN           NaN          26048
# mean     2010.926398    462.350636   1248.902096            NaN
# std        11.915875    423.476259   1066.102020            NaN
# min      1799.000000      1.000000    226.000000            NaN
# 25%      2010.000000    130.000000    678.000000            NaN
# 50%      2014.000000    366.000000    958.000000            NaN
# 75%      2016.000000    646.000000   1356.000000            NaN
# max      2021.000000   2203.000000  15000.000000            NaN
#
#         accessibility  date_listed         price
# count           26048        26048  2.604800e+04
# unique              1          359           NaN
# top           guarded   2021-10-12           NaN
# freq            26048         1728           NaN
# mean              NaN          NaN  2.994669e+06
# std               NaN          NaN  4.324294e+06
# min               NaN          NaN  5.566000e+05
# 25%               NaN          NaN  1.331000e+06
# 50%               NaN          NaN  1.851800e+06
# 75%               NaN          NaN  2.948000e+06
# max               NaN          NaN  7.480000e+07
#
# [11 rows x 23 columns]

# %% [markdown]
# ## unique values

# %% [markdown]
# It is meaningless to find a variable with only one value through unique: market_segment, type_of_area, eco_category, accessibility can be discarded

# %%
data_raw.nunique()
# Out:
# listing_id        26048
# name               1650
# street             3442
# type                  2
# model                14
# market_segment        1
# type_of_area          1
# bedrooms             17
# bathrooms             9
# district             27
# region                5
# planning_area        38
# subszone            193
# lat                3118
# lng                3118
# tenure               53
# built_year           60
# no_of_units         526
# area_size          1178
# eco_category          1
# accessibility         1
# date_listed         359
# price              4704
# dtype: int64

# %%
data_raw.drop(columns=["market_segment", "type_of_area", "eco_category", "accessibility"], inplace=True)

# %% [markdown]
# ## observe the value of each variable

# %%
var_ls=list(data_raw.columns)
var_ls
# Out:
# ['listing_id',
#  'name',
#  'street',
#  'type',
#  'model',
#  'bedrooms',
#  'bathrooms',
#  'district',
#  'region',
#  'planning_area',
#  'subszone',
#  'lat',
#  'lng',
#  'tenure',
#  'built_year',
#  'no_of_units',
#  'area_size',
#  'date_listed',
#  'price']

# %%
for i in var_ls:
    print("variable {0} : {1}".format(i,data_raw[i].unique()))
# Out:
# variable listing_id : [6998418 2046604 7563513 ... 2402528 8150354 8675194]
# variable name : ['seascape' 'la maison' 'viva' ... 'kembangan plaza' 'the grandhill'
#  'beauty world centre']
# variable street : ['57 cove way ' '10 moulmein rise ' '2 suffolk walk ' ... '71 oxley rise '
#  '301 jalan bukit ho swee ' '12b cairnhill rise ']
# variable type : ['condominium' 'apartment']
# variable model : ['condominium' 'apartment' 'executive condominium' nan 'walk-up apt'
#  'townhouse' 'soho' 'penthouse' 'duplex' 'high rise'
#  'residential with commercial on level 1' 'with pool' 'low rise'
#  'shophouse' 'strata terrace']
# variable bedrooms : ['3' '4' '2' '1' '3+1' '1+1' '2+1' nan '5' '4+1' '7' '5+1' '6' '3+2' '2+2'
#  '9' '8' '4+2']
# variable bathrooms : [ 4.  3.  2.  1. nan  5.  6.  7.  8. 10.]
# variable district : [ 4 11 14 15 27 23 19  7  2 10 18 16  1  6  3  5  9 28 13 21 17  8 22 12
#  20 25 26]
# variable region : ['central region' 'east region' 'north region' 'west region'
#  'north-east region']
# variable planning_area : ['southern islands' 'novena' 'bedok' 'sembawang' 'bukit batok' 'sengkang'
#  'downtown core' 'newton' 'tampines' 'kallang' 'bukit merah'
#  'choa chu kang' 'bukit timah' 'outram' 'queenstown' 'river valley'
#  'singapore river' 'toa payoh' 'hougang' 'tanglin' 'pasir ris' 'geylang'
#  'museum' 'clementi' 'serangoon' 'jurong east' 'orchard' 'yishun'
#  'marine parade' 'bukit panjang' 'jurong west' 'ang mo kio' 'rochor'
#  'bishan' 'punggol' 'woodlands' 'mandai' 'changi']
# variable subszone : ['sentosa' 'moulmein' 'kaki bukit' 'frankel' 'sembawang springs'
#  'hillview' 'compassvale' 'city hall' 'anson' 'orange grove' 'bugis'
#  'tampines east' 'bedok south' 'bedok north' 'tanjong rhu'
#  'central subzone' 'kampong tiong bahru' 'keat hong' 'leedon park'
#  "pearl's hill" 'kent ridge' 'maritime square' 'one tree hill'
#  'robertson quay' 'fernvale' 'cairnhill' 'sennett' 'bukit ho swee'
#  'pasir panjang 2' 'lorong ah soo' 'leonie hill' 'joo seng' 'nassim'
#  'anak bukit' 'flora drive' 'aljunied' 'bidadari' 'swiss club' 'kangkar'
#  'farrer court' 'institution hill' 'dhoby ghaut' 'everton park'
#  'sunset way' 'holland road' 'margaret drive' 'oxley' 'lorong chuan'
#  'lavender' 'one north' 'sembawang east' 'kovan' 'serangoon garden'
#  'west coast' 'jurong gateway' 'nicoll' 'balestier' 'tanglin'
#  'clarke quay' 'lower seletar' 'braddell' 'simei' 'seletar hills'
#  'mountbatten' 'dairy farm' 'clementi west' 'marine parade'
#  'upper paya lebar' 'boulevard' 'potong pasir' 'ulu pandan'
#  'yishun central' 'bendemeer' 'faber' 'taman jurong' 'cecil'
#  'pasir ris central' 'kampong java' 'tanjong pagar' 'kembangan'
#  'alexandra north' 'malcolm' 'coronation road' 'pasir ris park'
#  'kebun bahru' 'chatsworth' 'yishun east' 'mount emily' 'upper thomson'
#  'punggol town centre' 'clementi woods' 'pasir ris west' 'tiong bahru'
#  'marymount' 'mei chin' 'loyang east' 'tampines west' 'xilin' 'anchorvale'
#  'jelebu' 'tiong bahru station' 'woodlands east' 'hong kah' 'woodgrove'
#  'geylang east' 'guilin' 'boon teck' 'tyersall' 'sengkang town centre'
#  'matilda' 'gombak' 'bedok reservoir' 'mackenzie' 'bangkit'
#  'holland drive' 'teck whye' 'jurong west central' 'siglap' 'farrer park'
#  'yio chu kang east' 'macpherson' 'chinatown' 'pasir panjang 1'
#  'mandai estate' 'woodlands south' 'redhill' 'hougang central'
#  'kampong bugis' 'newton circus' 'nee soon' 'boon keng' 'yishun west'
#  'woodleigh' 'sembawang hills' 'bencoolen' "monk's hill" 'rivervale'
#  'hougang east' 'telok blangah drive' 'goodwood park' 'crawford'
#  'pasir ris drive' 'serangoon central' 'yio chu kang west'
#  'choa chu kang central' 'yunnan' 'ridout' 'bayshore' 'yishun south'
#  'punggol field' 'brickworks' 'sembawang central' 'yuhua east' 'boat quay'
#  'yew tee' 'bishan east' 'dunearn' 'paterson' 'katong' 'toa payoh central'
#  'saujana' 'depot road' "people's park" 'trafalgar' 'tai seng' 'somerset'
#  '2021-02-24' '2021-08-25' '2021-05-02' '2021-09-11' '2021-02-23'
#  '2021-06-08' '2021-05-23' '2021-01-11' '2021-08-17' '2021-03-28'
#  '2021-09-06' '2021-06-05' '2021-06-16' '2021-07-23' '2021-02-19'
#  '2021-01-15' '2021-04-07' '2021-02-10' '2021-04-19' '2021-09-18'
#  '2021-05-30' '2021-07-12' '2021-06-29' '2021-02-15' '2021-07-18'
#  '2021-04-24' '2021-07-25' '2021-04-10' '2021-03-23' '2021-01-16'
#  '2021-09-19' '2021-01-28' '2021-07-07' '2021-08-15' '2021-04-08'
#  '2021-08-18' '2021-01-30' '2021-05-14' '2021-07-08' '2021-08-08'
#  '2021-03-03' '2021-02-08' '2021-07-14' '2021-07-16' '2021-06-13'
#  '2021-05-11' '2021-07-05' '2021-04-22' '2021-06-27' '2021-03-24'
#  '2021-07-27' '2021-05-13' '2021-05-08' '2021-03-08' '2021-02-06'
#  '2020-08-19' '2021-08-19' '2021-06-06' '2021-05-21' '2021-09-16'
#  '2021-03-26' '2021-02-02' '2021-03-22' '2021-04-02' '2021-06-17'
#  '2021-01-31' '2021-04-17' '2021-02-04' '2021-04-23' '2021-06-14'
#  '2021-04-06' '2021-04-04' '2021-09-21' '2021-02-22' '2021-07-22'
#  '2021-05-15' '2021-03-18' '2021-07-26' '2021-05-10' '2021-03-20'
#  '2021-08-07' '2021-05-09' '2021-03-29' '2021-06-18' '2021-03-21'
#  '2021-01-27' '2021-03-30' '2021-02-16' '2021-01-24' '2021-02-27'
#  '2021-02-13' '2021-01-10' '2021-03-09' '2021-01-13' '2021-08-21'
#  '2021-04-01' '2021-07-20' '2021-02-07' '2021-03-10' '2021-01-23'
#  '2020-09-15' '2021-01-04' '2021-01-08' '2021-02-28' '2021-02-11'
#  '2021-01-14' '2021-07-09' '2021-02-18' '2021-03-06']
# variable price : [5390000. 2310000. 5279500. ... 1230500. 2383100. 4160000.]

# %% [markdown]
# ## related thinking(discuessed in the meeting)

# %% [markdown]
# 1）
#
# 'type' is a nominal variable and can be handled one-hot
#
# 'model' is a subdivision of 'type', what does the relationship look like?
#
# There is 'nan' in it that needs to be completed

# %% [markdown]
# 2）
#
# 'bedrooms' has the values of "3+1', '4+1', you need to know the meaning

# %% [markdown]
# 3）
#
# 'bathrooms' is of type float and needs to be changed to type int

# %% [markdown]
# 4）
#
# 'tenure' has a value like '956 years from 27/05/1928', which needs to be processed to become a value like '999 years'. Segmentation can then be performed.

# %% [markdown]
# 5）
#
# 'built_year' is of type float and needs to be changed to type int

# %% [markdown]
# 6）
#
# 'no_of_units' , Describe how big this apartment is, can it be clustered or segmented?

# %% [markdown]
# 7）
#
# The value '2021-05-04' in 'date_listed' needs to be changed to timestamp format

# %% [markdown]
# 8)
#
# For missing data, you can try to get the value through the correspondence of other variables. For example, through the name of the community, the type of apartment, and the corresponding year of construction.
