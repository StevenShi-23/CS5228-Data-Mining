# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


import seaborn as sns       

from scipy import stats
from scipy.stats import  norm
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data_train = pd.read_csv("train.csv")

# %%
pd.set_option('display.max_columns', None)
data_train
# Out:
#        listing_id                  name                street         type  \
# 0         6998418              seascape          57 cove way   condominium
# 1         2046604             la maison     10 moulmein rise     apartment
# 2         7563513                  viva       2 suffolk walk   condominium
# 3         3071445       urban treasures      205 jalan eunos   condominium
# 4         9667539  infini at east coast       east coast road    apartment
# ...           ...                   ...                   ...          ...
# 26043     2322717            citylights         jellicoe road  condominium
# 26044     3161844           dalvey haus      101 dalvey road   condominium
# 26045     2402528          my manhattan    25 simei street 3   condominium
# 26046     8150354             j gateway         gateway drive  condominium
# 26047     8675194       canberlin lodge  69 lorong 6 geylang     apartment
#
#              model market_segment type_of_area bedrooms  bathrooms  district  \
# 0      condominium            ocr       strata        3        4.0         4
# 1        apartment            ocr       strata        3        3.0        11
# 2      condominium            ocr       strata        4        3.0        11
# 3      condominium            ocr       strata        3        2.0        14
# 4        apartment            ocr       strata        3        3.0        15
# ...            ...            ...          ...      ...        ...       ...
# 26043  condominium            ocr       strata        3        3.0         8
# 26044  condominium            ocr       strata        3        3.0        10
# 26045  condominium            ocr       strata        2        2.0        18
# 26046  condominium            ocr       strata        4        3.0        22
# 26047    apartment            ocr       strata        3        4.0        14
#
#                region     planning_area        subszone       lat         lng  \
# 0      central region  southern islands         sentosa  1.239337  103.837487
# 1      central region            novena        moulmein  1.319533  103.847030
# 2      central region            novena        moulmein  1.315656  103.844445
# 3         east region             bedok      kaki bukit  1.329367  103.905791
# 4         east region             bedok         frankel  1.309176  103.911352
# ...               ...               ...             ...       ...         ...
# 26043  central region           kallang        lavender  1.308896  103.863069
# 26044  central region           tanglin          nassim  1.316263  103.825190
# 26045     east region          tampines           simei  1.341303  103.953348
# 26046     west region       jurong east  jurong gateway  1.335557  103.742417
# 26047  central region           geylang        aljunied  1.309446  103.876929
#
#                    tenure  built_year  no_of_units  area_size   eco_category  \
# 0      leasehold/99 years      2011.0        151.0     2336.0  uncategorized
# 1                freehold      1999.0         24.0     1259.0  uncategorized
# 2                freehold      2012.0        235.0     1959.0  uncategorized
# 3                freehold         NaN        237.0      883.0  uncategorized
# 4                freehold         NaN         36.0     1066.0  uncategorized
# ...                   ...         ...          ...        ...            ...
# 26043  leasehold/99 years      2007.0        600.0     1442.0  uncategorized
# 26044            freehold         NaN         17.0     1561.0  uncategorized
# 26045  leasehold/99 years      2014.0        301.0      883.0  uncategorized
# 26046  leasehold/99 years      2016.0        738.0     1206.0  uncategorized
# 26047            freehold      2001.0         14.0     1152.0  uncategorized
#
#       accessibility date_listed      price
# 0           guarded  2021-05-04  5390000.0
# 1           guarded  2021-05-07  2310000.0
# 2           guarded  2021-06-30  5279500.0
# 3           guarded  2022-01-02  1843600.0
# 4           guarded  2021-12-24  2262700.0
# ...             ...         ...        ...
# 26043       guarded  2021-12-14  2750000.0
# 26044       guarded  2022-01-05  6449300.0
# 26045       guarded  2021-06-23  1306800.0
# 26046       guarded  2021-10-23  2420000.0
# 26047       guarded  2021-08-31  1375000.0
#
# [26048 rows x 23 columns]

# %%
data_train['price'].describe()
# Out:
# count    2.604800e+04
# mean     2.994669e+06
# std      4.324294e+06
# min      5.566000e+05
# 25%      1.331000e+06
# 50%      1.851800e+06
# 75%      2.948000e+06
# max      7.480000e+07
# Name: price, dtype: float64

# %%
a=data_train['price']/1000000

# %%
sns.distplot(a)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
a.describe()
# Out:
# count    26048.000000
# mean         2.994669
# std          4.324294
# min          0.556600
# 25%          1.331000
# 50%          1.851800
# 75%          2.948000
# max         74.800000
# Name: price, dtype: float64

# %%
#skewness and kurtosis
print("Skewness: %f" % a.skew())
print("Kurtosis: %f" % a.kurt())
# Out:
# Skewness: 7.801323
# Kurtosis: 89.644928

# %%
print("Skewness: %f" % data_train['price'].skew())
print("Kurtosis: %f" % data_train['price'].kurt())
# Out:
# Skewness: 7.793932
# Kurtosis: 89.321184

# %%
data_train.columns
# Out:
# Index(['listing_id', 'name', 'street', 'type', 'model', 'market_segment',
#        'type_of_area', 'bedrooms', 'bathrooms', 'district', 'region',
#        'planning_area', 'subszone', 'lat', 'lng', 'tenure', 'built_year',
#        'no_of_units', 'area_size', 'eco_category', 'accessibility',
#        'date_listed', 'price'],
#       dtype='object')

# %%
var = 'type'
data = pd.concat([a, data_train[var]], axis=1)
fig = sns.boxplot(x=var, y="price", data=data)

# %%
var = 'bathrooms'
data = pd.concat([a, data_train[var]], axis=1)
fig = sns.boxplot(x=var, y="price", data=data)

# %%
var = 'bedrooms'
data = pd.concat([a, data_train[var]], axis=1)
fig = sns.boxplot(x=var, y="price", data=data)

# %%
var = 'district'
data = pd.concat([a, data_train[var]], axis=1)
fig = sns.boxplot(x=var, y="price", data=data)

# %%
var = 'tenure'
data = pd.concat([a, data_train[var]], axis=1)
fig = sns.boxplot(x=var, y="price", data=data)

# %%
p1=sns.barplot( data=data_train, y='tenure', x='price' )
plt.show()

# %%
data_train['built_year'].describe()
# Out:
# count    16005.000000
# mean      2010.926398
# std         11.915875
# min       1799.000000
# 25%       2010.000000
# 50%       2014.000000
# 75%       2016.000000
# max       2021.000000
# Name: built_year, dtype: float64

# %%
var = 'built_year'
data = pd.concat([a, data_train[var]], axis=1)
data.plot.scatter(x=var, y='price')
# Out:
# <AxesSubplot:xlabel='built_year', ylabel='price'>

# %%
var = 'no_of_units'
data = pd.concat([a, data_train[var]], axis=1)
data.plot.scatter(x=var, y='price')
# Out:
# <AxesSubplot:xlabel='no_of_units', ylabel='price'>

# %%
var  = 'area_size'
data = pd.concat([a, data_train[var]], axis=1)
data.plot.scatter(x=var, y='price')
# Out:
# <AxesSubplot:xlabel='area_size', ylabel='price'>

# %%
var = 'built_year'
data = pd.concat([data_train['price'], data_train[var]], axis=1)
f, ax = plt.subplots(figsize=(26, 12))
fig = sns.boxplot(x=var, y="price", data=data)

# %%
data_train = pd.read_csv("corr_plot.csv")

# %%
data_train.head()
# Out:
#    Unnamed: 0  listing_id                  name             street  \
# 0           0     6998418              seascape       57 cove way
# 1           1     2046604             la maison  10 moulmein rise
# 2           2     7563513                  viva    2 suffolk walk
# 3           3     3071445       urban treasures   205 jalan eunos
# 4           4     9667539  infini at east coast    east coast road
#
#           type  bathrooms  district          region     planning_area  \
# 0  condominium        4.0         4  central region  southern islands
# 1    apartment        3.0        11  central region            novena
# 2  condominium        3.0        11  central region            novena
# 3  condominium        2.0        14     east region             bedok
# 4    apartment        3.0        15     east region             bedok
#
#      subszone  built_year  no_of_units  area_size date_listed      price  \
# 0     sentosa      2011.0        151.0     2336.0  2021-05-04  5390000.0
# 1    moulmein      1999.0         24.0     1259.0  2021-05-07  2310000.0
# 2    moulmein      2012.0        235.0     1959.0  2021-06-30  5279500.0
# 3  kaki bukit      1930.0        237.0      883.0  2022-01-02  1843600.0
# 4     frankel      2022.0         36.0     1066.0  2021-12-24  2262700.0
#
#    bedrooms  tenure_remains  tenure_years  comme_min_distance  comme_no_1km  \
# 0       3.0              99            99            3.465477             0
# 1       3.0         1000000           999            0.253532             2
# 2       4.0         1000000           999            0.308259             1
# 3       3.0         1000000           999            1.146688             0
# 4       3.0         1000000           999            1.380337             0
#
#    comme_no_3km  gov-m_min_distance  gov-m_no_1km  gov-m_no_3km  \
# 0             0            2.523949             0             7
# 1             6            0.322039             5            44
# 2             5            0.402367             5            45
# 3             3            0.632724             2            29
# 4             1            0.384105             4            25
#
#    shopp_min_distance  shopp_no_1km  shopp_no_3km  secon_min_distance  \
# 0            1.992149             0             6            2.739930
# 1            0.210706            11            70            0.786247
# 2            0.124587            11            70            0.668196
# 3            1.044382             0            25            0.308054
# 4            0.510369             7            18            0.388370
#
#    secon_no_1km  secon_no_3km  prima_min_distance  prima_no_1km  prima_no_3km  \
# 0             0             1            2.511796             0             3
# 1             3            27            0.145587             7            35
# 2             1            28            0.182761             7            34
# 3             1            30            0.300643             4            33
# 4             3            20            0.232984             6            22
#
#    train_min_distance  train_no_1km  train_no_3km
# 0            2.110841             0             7
# 1            0.230193             5            53
# 2            0.331496             5            50
# 3            0.426680             5            24
# 4            0.822432             2            18

# %%
data_train.drop(columns=['Unnamed: 0', 'listing_id', 'name','street', 'type',
                       'region', 'planning_area', 'subszone', 'date_listed', 
                      'tenure_remains', 'comme_min_distance', 'comme_no_1km',
       'comme_no_3km', 'gov-m_min_distance', 'gov-m_no_1km', 'gov-m_no_3km',
       'shopp_min_distance', 'shopp_no_1km', 'shopp_no_3km',
       'secon_min_distance', 'secon_no_1km', 'secon_no_3km',
       'prima_min_distance', 'prima_no_1km', 'prima_no_3km',
       'train_min_distance', 'train_no_1km', 'train_no_3km'  ],inplace=True)

# %%
data_train.columns
# Out:
# Index(['bathrooms', 'district', 'built_year', 'no_of_units', 'area_size',
#        'price', 'bedrooms', 'tenure_years'],
#       dtype='object')

# %%
corrmat = data_train.corr()
f, ax = plt.subplots(figsize=(20, 9))
sns.heatmap(corrmat, vmax=0.8, square=True)
# Out:
# <AxesSubplot:>

# %%
k  = 10 # 关系矩阵中将显示10个特征
cols = corrmat.nlargest(k, 'price')['price'].index
cm = np.corrcoef(data_train[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, \
                 square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
data_train.columns
# Out:
# Index(['bathrooms', 'district', 'built_year', 'no_of_units', 'area_size',
#        'price', 'bedrooms', 'tenure_years'],
#       dtype='object')

# %%
sns.set()
cols = ['price','bathrooms', 'district', 'built_year', 'no_of_units', 'area_size',
        'bedrooms', 'tenure_years']
sns.pairplot(data_train[cols], size = 2.5)
plt.show()
